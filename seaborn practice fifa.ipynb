# %% [markdown]
# ### Explorations: Make your dream team Analyse which Club or National Team has the best-rated players Assess the strength of a team at a particular position
# ### Analyse the team with the best dribbling speed
# ### Co-relate between Age and Overall rating
# ### Co-relate between Age and Nationality
# ### Co-relate between Age and Potential

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# C:\Users\OWNER\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df=pd .read_csv(r"F:\Data Science_1March_Komal\fifa19\data.csv")
#tips = sns.load_dataset(r"F:\Data Science_1March_Komal\fifa19\data.csv")
df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
df['Continent']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Continent'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-4f67814db93c> in <module>
# ----> 1 df['Continent']
#
# ...

# %%
df1=df[['Name', 'Age', 'Nationality','Overall','Potential']]# 'Preferred Positions']]
df1.head(10)
df1.shape
df1.columns
# Out:
# Index(['Name', 'Age', 'Nationality', 'Overall', 'Potential'], dtype='object')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
tc = df1.corr() #Pivot Table or Correlation data
tc
# Out:
#                 Age   Overall  Potential
# Age        1.000000  0.452350  -0.253312
# Overall    0.452350  1.000000   0.660939
# Potential -0.253312  0.660939   1.000000

# %%
sns.heatmap(tc,annot=True) #Here, color on the basis of gradient scale

# %%
df.shape
# Out:
# (18207, 89)

# %%
df.nunique()
# Out:
# Unnamed: 0        18207
# ID                18207
# Name              17194
# Age                  29
# Photo             18207
#                   ...
# GKHandling           70
# GKKicking            79
# GKPositioning        79
# GKReflexes           76
# Release Clause     1244
# Length: 89, dtype: int64

# %%
df.isnull().any()
# Out:
# Unnamed: 0        False
# ID                False
# Name              False
# Age               False
# Photo             False
#                   ...
# GKHandling         True
# GKKicking          True
# GKPositioning      True
# GKReflexes         True
# Release Clause     True
# Length: 89, dtype: bool

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
# Max number of Player's Nationality
plt.figure(figsize=(20,10))
plt.title('Players by Nationality')
plt.xlabel('No.of players')
plt.ylabel('Players Nationality')
lplt=sns.countplot(x = df.Nationality,data=df,order=df['Nationality'].value_counts().sort_values(ascending=False).index)
lplt.set(xlim=(0,20))

plt.show()

# %% [markdown]
# ### Histogram: number of players's age

# %%
plt.figure(figsize=(10,5))
sns.countplot(x="Age", data=df)
plt.xlabel("Age of playes",fontsize=15)
plt.ylabel("Number of playes",fontsize=15)
plt.title("Age wise Number of players")
# Out:
# Text(0.5, 1.0, 'Age wise Number of players')

# %%
# Player's Nationality by Count
df["Nationality"].value_counts().head(20)
# Out:
# England                1662
# Germany                1198
# Spain                  1072
# Argentina               937
# France                  914
# Brazil                  827
# Italy                   702
# Colombia                618
# Japan                   478
# Netherlands             453
# Sweden                  397
# China PR                392
# Chile                   391
# Republic of Ireland     368
# Mexico                  366
# United States           353
# Poland                  350
# Norway                  341
# Saudi Arabia            340
# Denmark                 336
# Name: Nationality, dtype: int64

# %%
# Top 5 right-footed players
df[df['Preferred Foot'] == 'Right'][['Name','Overall']].head()
# Out:
#                 Name  Overall
# 1  Cristiano Ronaldo       94
# 2          Neymar Jr       92
# 3             De Gea       91
# 4       K. De Bruyne       91
# 5          E. Hazard       91

# %%
# Top five the most expensive clubs
df.groupby(['Club']).sum().head(5)#.sort_values(ascending = False).head(5) #['Value_float'].sum().sort_values(ascending = False).head(5)
# Out:
#                        Unnamed: 0       ID  Age  Overall  Potential  Special  \
# Club
#  SSV Jahn Regensburg       272754  6352723  744     1902       2010    44680
# 1. FC Heidenheim 1846      259796  6152556  672     1841       2014    43784
# 1. FC Kaiserslautern       298888  5742054  620     1648       1817    39631
# 1. FC Köln                 146749  5834884  681     1982       2144    46807
# 1. FC Magdeburg            247367  5888687  642     1706       1829    39850
#
#                        International Reputation  Weak Foot  Skill Moves  \
# Club
#  SSV Jahn Regensburg                       29.0       90.0         65.0
# 1. FC Heidenheim 1846                      28.0       83.0         65.0
# 1. FC Kaiserslautern                       26.0       82.0         58.0
# 1. FC Köln                                 37.0       85.0         68.0
# 1. FC Magdeburg                            27.0       86.0         55.0
#
# ...

# %%
# Player's Overall Performance
plt.figure(figsize=(20,10))
plt.title('Players by Overall')
plt.xlabel('No. of players')
plt.ylabel('Players Overall')
sns.countplot(x="Overall", data=df)
plt.show()

# %% [markdown]
# #### Hence, we can deduce that the maximum number of players peroformance is participating in FIFA lie

# %%
# Player's Position
plt.figure(figsize=(20,10))
plt.title('Player Position')
plt.xlabel('No. of players')
plt.ylabel('Player Position')
sns.countplot(x="Position", data=df)
plt.show()

# %%
fifaheat = df

fifaheat.head(5)
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
sns.distplot(df['Age']) # Here, line is KDE - Kernel density estimate, output is Histogram.

# %%
plt.figure(figsize=(16,8))
plt.xlabel('Number of players', fontsize=15)
plt.ylabel('Players Age', fontsize=15)
#sns.x='Nationality',y='Potential'
sns.countplot(x="Nationality", data=df, palette="hls");
plt.show()

# %% [markdown]
# ### Maximum number of players belong to which country?

# %%
sns.bar(x='Age',data=df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-7e4d3a05107a> in <module>
# ----> 1 sns.bar(x='Age',data=df)
#
# AttributeError: module 'seaborn' has no attribute 'bar'

# %%
sns.set(style ="dark", palette="colorblind", color_codes=True)
x = df.Age
y=df.Potential
plt.figure(figsize=(12,8))
ax = sns.distplot(x, bins = 58, kde = False, color='g')
ax.set_xlabel(xlabel="Player\'s age", fontsize=16)
ax.set_ylabel(ylabel='Number of players', fontsize=16)
ax.set_title(label='Histogram of players age', fontsize=20)
plt.show()

# %%
sns.jointplot(x='Age', y='Potential', data=df,kind="hex", color="gray");

# %%
sns.jointplot(x='Age', y='Overall', data=df, color="gray");

# %% [markdown]
# #### Agewise most skilled person in fifa

# %%
plt.figure(figsize=(10, 6))

Skill_Moves =df.sort_values(by=['Skill Moves'], ascending=False).head(10)

plt.bar(Skill_Moves["Name"],Skill_Moves["Age"],color="g")
#p.head().plot(kind="bar")


plt.ylabel("Age")
plt.xlabel("Name")

plt.title("most skilled players in fifa", fontsize = 18)
plt.show()

# %%
#sns.jointplot(x='Age', y='Nationality', data=df, color="gray");
sns.pairplot(df,hue='Age',kind='reg',vars=['Age','Nationality']) #Here, 'sex' columns is categorical column
# Out:
# C:\Users\OWNER\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\OWNER\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# C:\Users\OWNER\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\OWNER\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# C:\Users\OWNER\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# ...

# %%
plt.hist(df.Age)
# Out:
# (array([1.063e+03, 3.687e+03, 4.030e+03, 3.868e+03, 2.977e+03, 1.689e+03,
#         7.270e+02, 1.440e+02, 1.900e+01, 3.000e+00]),
#  array([16. , 18.9, 21.8, 24.7, 27.6, 30.5, 33.4, 36.3, 39.2, 42.1, 45. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(df.Potential)
# Out:
# (array([  16.,  102., 1007., 2973., 5645., 4908., 2185., 1097.,  245.,
#           29.]),
#  array([48. , 52.7, 57.4, 62.1, 66.8, 71.5, 76.2, 80.9, 85.6, 90.3, 95. ]),
#  <a list of 10 Patch objects>)

# %%
## Co-relate between Age and Overall rating 
df.groupby('Age')['Overall'].agg(max)
# Out:
# Age
# 16    64
# 17    77
# 18    82
# 19    88
# 20    81
# 21    83
# 22    86
# 23    86
# 24    89
# 25    90
# 26    92
# 27    91
# 28    90
# 29    90
# 30    89
# 31    94
# 32    91
# 33    94
# 34    86
# 35    85
# 36    85
# 37    84
# 38    74
# 39    80
# 40    88
# 41    77
# 42    65
# 44    53
# 45    71
# Name: Overall, dtype: int64

# %%
df.groupby('Age')['Nationality'].agg(max)
# Out:
# Age
# 16        United States
# 17                Wales
# 18               Zambia
# 19               Zambia
# 20               Zambia
# 21               Zambia
# 22             Zimbabwe
# 23                Wales
# 24             Zimbabwe
# 25                Wales
# 26             Zimbabwe
# 27             Zimbabwe
# 28             Zimbabwe
# 29               Zambia
# 30             Zimbabwe
# 31                Wales
# 32             Zimbabwe
# 33                Wales
# 34             Zimbabwe
# 35                Wales
# 36        United States
# 37                Wales
# 38               Turkey
# 39        United States
# 40         Saudi Arabia
# 41         Saudi Arabia
# 42                Japan
# 44    Trinidad & Tobago
# 45               Mexico
# Name: Nationality, dtype: object

# %%
df.groupby('Age')['Potential'].agg(max)
# Out:
# Age
# 16    86
# 17    92
# 18    91
# 19    95
# 20    90
# 21    92
# 22    92
# 23    92
# 24    94
# 25    93
# 26    93
# 27    93
# 28    90
# 29    90
# 30    89
# 31    94
# 32    91
# 33    94
# 34    86
# 35    85
# 36    85
# 37    84
# 38    74
# 39    80
# 40    88
# 41    77
# 42    65
# 44    53
# 45    71
# Name: Potential, dtype: int64

# %%
df['Photo']
# Out:
# 0        https://cdn.sofifa.org/players/4/19/158023.png
# 1         https://cdn.sofifa.org/players/4/19/20801.png
# 2        https://cdn.sofifa.org/players/4/19/190871.png
# 3        https://cdn.sofifa.org/players/4/19/193080.png
# 4        https://cdn.sofifa.org/players/4/19/192985.png
#                               ...
# 18202    https://cdn.sofifa.org/players/4/19/238813.png
# 18203    https://cdn.sofifa.org/players/4/19/243165.png
# 18204    https://cdn.sofifa.org/players/4/19/241638.png
# 18205    https://cdn.sofifa.org/players/4/19/246268.png
# 18206    https://cdn.sofifa.org/players/4/19/246269.png
# Name: Photo, Length: 18207, dtype: object

# %%
df.describe()
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  18207.000000   18207.000000  18207.000000  18207.000000  18207.000000
# mean    9103.000000  214298.338606     25.122206     66.238699     71.307299
# std     5256.052511   29965.244204      4.669943      6.908930      6.136496
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     4551.500000  200315.500000     21.000000     62.000000     67.000000
# 50%     9103.000000  221759.000000     25.000000     66.000000     71.000000
# 75%    13654.500000  236529.500000     28.000000     71.000000     75.000000
# max    18206.000000  246620.000000     45.000000     94.000000     95.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  18207.000000              18159.000000  18159.000000  18159.000000
# mean    1597.809908                  1.113222      2.947299      2.361308
# ...

# %%
#sns.pairplot(df,hue='Age',kind='scatter',palette='summer',vars=['Age','Overall'])
sns.pairplot(hue='Age',data=df)
# Out:
# C:\Users\OWNER\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\OWNER\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# C:\Users\OWNER\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\OWNER\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# C:\Users\OWNER\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# ...

# %%
Agerate_arr=df[['Age','Overall']]
new=np.array(Agerate_arr)
new
plt.violinplot(new,showmedians=True)
ax = sns.heatmap(new,annot=True)

# %%
plt.boxplot(new);

# %%
#scattered plotting for corealting age and oerall
plt.figure(figsize=(16,8))
plt.title('Players value according to their Age and Overall', fontsize=20, fontweight='bold', y=1.05,)
plt.xlabel('Age', fontsize=15)
plt.ylabel('Overall', fontsize=15)
plt.scatter(df['Age'],df['Overall']) #s = value/100000, edgecolors='black')
plt.show()

# %%
#sns.lmplot(x='Age',y='Overall',data=df,)

# %%
df['Club']
# Out:
# 0               FC Barcelona
# 1                   Juventus
# 2        Paris Saint-Germain
# 3          Manchester United
# 4            Manchester City
#                 ...
# 18202        Crewe Alexandra
# 18203         Trelleborgs FF
# 18204       Cambridge United
# 18205        Tranmere Rovers
# 18206        Tranmere Rovers
# Name: Club, Length: 18207, dtype: object

# %%
df[df['Dribbling'].value_counts().head(5)]['Club']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-51aaf083b2c0> in <module>
# ----> 1 df[df['Dribbling'].value_counts().head(5)]['Club']
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1551
#    1552         self._validate_read_indexer(
# -> 1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#    1555         return keyarr, indexer
#
# ...

# %%
df.groupby('Club').count()['Dribbling']
#sns.distplot(arr)
# Out:
# Club
#  SSV Jahn Regensburg     29
# 1. FC Heidenheim 1846    28
# 1. FC Kaiserslautern     26
# 1. FC Köln               28
# 1. FC Magdeburg          26
#                          ..
# Zagłębie Sosnowiec       25
# Çaykur Rizespor          30
# Örebro SK                27
# Östersunds FK            22
# Śląsk Wrocław            24
# Name: Dribbling, Length: 651, dtype: int64

# %%
#team with highest dribbling
a1=df.loc[df['Dribbling'].idxmax()]
a1['Club']
# Out:
# 'FC Barcelona'

# %%
#team with min dribbling
a1=df.loc[df['Dribbling'].idxmin()]
a1['Club']
# Out:
# 'SV Zulte-Waregem'

# %%
sns.rugplot(df['Age'])

# %%
plt.rcParams['figure.figsize'] = (10, 5)
sns.heatmap(df[['Age', 'Nationality', 'Overall', 'Potential', 'Value']].corr(),annot=True)
plt.title('Histogram of the Dataset', fontsize = 30)
plt.show()

# %%
#The older the player (the more skilled the player), the higher the overall score.
#Age and Overall correlation coefficient: 0.45
# Correlation: Age Vs Overall¶


#plt.rcParams['figure.figsize'] = (10, 5)
plt.figure(figsize=(10,5))
ax = sns.relplot(x='Age', y='Overall', kind='line', data=df, linewidth=2)
ax.set_titles(label="Age Vs Overall Correlation", color='black')

# %%
df.groupby('Nationality').count()['Name']
# Out:
# Nationality
# Afghanistan      4
# Albania         40
# Algeria         60
# Andorra          1
# Angola          15
#               ...
# Uzbekistan       2
# Venezuela       67
# Wales          129
# Zambia           9
# Zimbabwe        13
# Name: Name, Length: 164, dtype: int64

# %%
#indian football members
def country(x):
    return df[df['Nationality'] == x][['Name','Overall','Potential','Position']]


# let's check the Indian Players 
country('India')
# Out:
#                   Name  Overall  Potential Position
# 8605        S. Chhetri       67         67       LS
# 10011       S. Jhingan       65         71      RCB
# 12598    J. Lalpekhlua       63         64       RS
# 12811  G. Singh Sandhu       63         68       GK
# 13508    A. Edathodika       62         62      LCB
# 14054        P. Halder       61         67      RCM
# 14199         P. Kotal       61         66       RB
# 14218         L. Ralte       61         62       LW
# 14705           N. Das       60         65       LB
# 14786         U. Singh       60         67       RM
# 14915       H. Narzary       60         66       LM
# 15356         R. Singh       59         59       ST
# 15643         S. Singh       59         65       CB
# 15652         A. Thapa       59         71      LCM
# 15855       M. Rafique       58         61       CM
# 15864         A. Singh       58         62       GK
# 15884         B. Singh       58         58       ST
# ...

# %% [markdown]
# #### countplot for analysing foot preference of the players¶

# %%
plt.figsize=(10,8)
sns.countplot(df['Preferred Foot'], palette = 'pink')
plt.title("most preffered foot of players")
# Out:
# Text(0.5, 1.0, 'most preffered foot of players')

# %% [markdown]
# ### Top 15 players

# %%
# Top 15 Players
Top_15 = df.sort_values(["Value"], ascending=False).head(15)
Top_15[["Name" ,"Age" ,"Nationality" ,"Club" ,"Position" ,"Value"]]
# Out:
#                    Name  Age  Nationality                 Club Position Value
# 1903       M. Gaćinović   23       Serbia  Eintracht Frankfurt       CM   €9M
# 1787          Joelinton   21       Brazil  TSG 1899 Hoffenheim       LS   €9M
# 1584  Lucas Evangelista   23       Brazil            FC Nantes       CM   €9M
# 2054         O. Kharbin   24        Syria             Al Hilal       ST   €9M
# 108                Pepe   35     Portugal          Beşiktaş JK      RCB   €9M
# 2052          M. Cornet   21  Ivory Coast   Olympique Lyonnais       RW   €9M
# 1578                Ivi   24        Spain   Real Valladolid CF       LM   €9M
# 1577            Francis   22        Spain           Real Betis       RM   €9M
# 102               Naldo   35       Brazil        FC Schalke 04       CB   €9M
# 896        B. Moukandjo   29     Cameroon     Beijing Renhe FC      CAM   €9M
# 1572          S. Fofana   23  Ivory Coast              Udinese      RCM   €9M
# ...

# %% [markdown]
# #### Count plot for work rate number of players

# %%
plt.figure(figsize = (15, 7))

sns.countplot(x = 'Work Rate', data = df, palette = 'hls')

# %% [markdown]
# ####  Clubwise overall performance

# %%
#df('Club').groupby(by='Overall',ascending=False)
df.groupby('Club').count()['Overall']
# Out:
# Club
#  SSV Jahn Regensburg     29
# 1. FC Heidenheim 1846    28
# 1. FC Kaiserslautern     26
# 1. FC Köln               28
# 1. FC Magdeburg          26
#                          ..
# Zagłębie Sosnowiec       25
# Çaykur Rizespor          30
# Örebro SK                27
# Östersunds FK            22
# Śląsk Wrocław            25
# Name: Overall, Length: 651, dtype: int64

# %%
some_clubs = ('CD Leganés', 'Southampton', 'RC Celta', 'Empoli', 'Fortuna Düsseldorf', 'Manchestar City',
             'Tottenham Hotspur', 'FC Barcelona', 'Valencia CF', 'Chelsea', 'Real Madrid')

data_clubs = df.loc[df['Club'].isin(some_clubs) & df['Overall']]

plt.rcParams['figure.figsize'] = (12, 8)
ax = sns.boxplot(x = data_clubs['Club'], y = data_clubs['Overall'], palette = 'inferno')
ax.set_xlabel(xlabel = 'Some Popular Clubs', fontsize = 9)
ax.set_ylabel(ylabel = 'Overall Score', fontsize = 9)
ax.set_title(label = 'Distribution of Overall Score in Different popular Clubs', fontsize = 20)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# #### youngest 10 players

# %%
young=df.sort_values('Age',ascending=True)[['Name','Age','Nationality','Club']].head(10)
young
# Out:
#                  Name  Age          Nationality             Club
# 18206       G. Nugent   16              England  Tranmere Rovers
# 17743       J. Olstad   16               Norway  Sarpsborg 08 FF
# 13293     H. Massengo   16               France        AS Monaco
# 16081     J. Italiano   16            Australia      Perth Glory
# 18166        N. Ayéva   16               Sweden        Örebro SK
# 17712        K. Broda   16               Poland     Wisła Kraków
# 17354     L. D'Arrigo   16            Australia  Adelaide United
# 13567  Y. Verschaeren   16              Belgium   RSC Anderlecht
# 16927       B. Nygren   16               Sweden     IFK Göteborg
# 18018     B. O'Gorman   16  Republic of Ireland   Bray Wanderers

# %% [markdown]
# #### Eldest 10 players

# %%
eld=df.sort_values('Age',ascending=False)[['Name','Age','Nationality','Club']].head(10)
eld
# Out:
#                 Name  Age        Nationality                          Club
# 4741        O. Pérez   45             Mexico                       Pachuca
# 18183  K. Pilkington   44            England              Cambridge United
# 17726      T. Warner   44  Trinidad & Tobago            Accrington Stanley
# 10545    S. Narazaki   42              Japan                Nagoya Grampus
# 7225        C. Muñoz   41          Argentina  CD Universidad de Concepción
# 1120       J. Villar   41           Paraguay                           NaN
# 12192   H. Sulaimani   41       Saudi Arabia                     Ohod Club
# 15426       M. Tyler   41            England           Peterborough United
# 4228        B. Nivet   41             France                  ESTAC Troyes
# 10356       F. Kippe   40             Norway                 Lillestrøm SK

# %%
import plotly.graph_objs as go
import plotly.graph_objects as go

# %%
layout = go.Layout(title = 'Country vs Ratings')

fig = go.Figure(data = df, layout = layout)
py.iplot(fig)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-04d417040974> in <module>
#       1 layout = go.Layout(title = 'Country vs Ratings')
#       2
# ----> 3 fig = go.Figure(data = df, layout = layout)
#       4 py.iplot(fig)
#
# ~\Anaconda3\lib\site-packages\plotly\graph_objs\_figure.py in __init__(self, data, layout, frames, skip_invalid, **kwargs)
#     582             is invalid AND skip_invalid is False
#     583         """
# --> 584         super(Figure, self).__init__(data, layout, frames, skip_invalid, **kwargs)
#     585
#     586     def add_area(
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in __init__(self, data, layout_plotly, frames, skip_invalid, **kwargs)
#     145         # ### Import traces ###
#     146         data = self._data_validator.validate_coerce(
# ...

# %%
sns.pairplot(df.iloc[:,1:6]) # All rows but columns 2-7

# %%
plt.figure(figsize=(15,8))
sns.set(style="whitegrid")
plt.xticks(rotation=60)
sns.violinplot(x='Club', y='Volleys', data=data_clubs, palette='muted')

#sns.barplot(x='Club', y='Volleys', data=df)
plt.title(label="Total number of goals scored by the 10 clubs")
# Out:
# Text(0.5, 1.0, 'Total number of goals scored by the 10 clubs')

# %%
top_clubs = df[['Name', 'Overall', 'Club']]
top10_clubs = top_clubs.groupby('Club', as_index=False).median().sort_values(by='Overall', ascending=False).head(10)
top10_clubs
# Out:
#                   Club  Overall
# 326           Juventus     84.0
# 214  FC Bayern München     83.0
# 212       FC Barcelona     82.0
# 374    Manchester City     81.0
# 315              Inter     81.0
# 61     Atlético Madrid     81.0
# 398             Napoli     81.0
# 583  Tottenham Hotspur     80.0
# 363          Liverpool     80.0
# 470        Real Madrid     80.0

# %%
top_10clubs = ['Juventus', 'FC Bayern München', 'FC Barcelona', 'Napoli', 'Atlético Madrid', 
               'Manchester City', 'Inter', 'Liverpool', 'Real Madrid', 'Tottenham Hotspur']
data_clubs = df.loc[df['Club'].isin(top_10clubs)]
data_clubs

plt.figure(figsize=(14,8))
ax = sns.violinplot(x='Club', y='Age', data=data_clubs, palette='muted')
ax.set_xlabel('Clubs', fontsize=18)
ax.set_ylabel('Age', fontsize=18)
ax.set_title(label='Distribution of Age Across Top 10 Clubs', fontsize=18, color='Black')
# Out:
# Text(0.5, 1.0, 'Distribution of Age Across Top 10 Clubs')

# %%
cdist = df.groupby(['Continent']).count()['Nationality'].sort_values(ascending=False).reset_index()
cdist
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-43c36bddf502> in <module>
# ----> 1 cdist = df.groupby(['Continent']).count()['Nationality'].sort_values(ascending=False).reset_index()
#       2 cdist
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed)
#    5808             group_keys=group_keys,
#    5809             squeeze=squeeze,
# -> 5810             observed=observed,
#    5811         )
#    5812
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated)
#     407                 sort=sort,
#     408                 observed=observed,
# --> 409                 mutated=self.mutated,
#     410             )
#     411
#
# ...

# %%
plt.figure(figsize=(10,4))

ax = sns.barplot(x=cdist['Continent'], y=cdist['Nationality'], palette='Set1')
ax.set_xlabel(xlabel = 'Continent', fontsize = 13)
ax.set_ylabel(ylabel = 'Nationality', fontsize = 13)
ax.set_title(label = 'Geographical Distribution of Players', fontsize = 15)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-031caa0c66cd> in <module>
#       1 plt.figure(figsize=(10,4))
#       2
# ----> 3 ax = sns.barplot(x=cdist['Continent'], y=cdist['Nationality'], palette='Set1')
#       4 ax.set_xlabel(xlabel = 'Continent', fontsize = 13)
#       5 ax.set_ylabel(ylabel = 'Nationality', fontsize = 13)
#
# NameError: name 'cdist' is not defined
